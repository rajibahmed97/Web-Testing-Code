# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
plt.plot([1, 2, 3, 4], [4, 4, 2, 3])

# %%
fig = plt.figure() #an empty figure with no axes

# %%
fig, ax = plt.subplots() #a figure with a single axes

# %%
fig, axs = plt.subplots(2,2) #a figure with 2x2 grid axes

# %%
num = np.random.rand(2,5)
type(num)
# Out:
# numpy.ndarray

# %%
a = pd.DataFrame(num, columns = list('abcde'))

# %%
peoples = {
    'first_name':['Rajib','Ahammad','Ali Ahmed'],
    'last_name':['Ahmed','Robiul','Hanif'],
    'email':['saidulislamrajib97@gmail.com','robiul@gmail.com','hanif@gmail.com']
}
a
# Out:
#           a         b         c         d         e
# 0  0.195000  0.194118  0.584955  0.254370  0.125469
# 1  0.314103  0.560734  0.317961  0.255123  0.992891

# %%
a_asarray = a.values
a.values
# Out:
# array([[0.19500036, 0.19411759, 0.58495467, 0.25437   , 0.12546918],
#        [0.31410266, 0.56073434, 0.31796058, 0.25512282, 0.99289125]])

# %%
number = np.arange(12).reshape(3,4)
result = pd.DataFrame(number, columns = list('abcd'))

# %%
result
# Out:
#    a  b   c   d
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
pd.DataFrame(peoples)
# Out:
#   first_name last_name                         email
# 0      Rajib     Ahmed  saidulislamrajib97@gmail.com
# 1    Ahammad    Robiul              robiul@gmail.com
# 2  Ali Ahmed     Hanif               hanif@gmail.com

# %%
b = np.matrix([[1,2],[3,4]])

# %%
type(b)
# Out:
# numpy.matrix

# %%
type(np.asarray(b)) #convert matrix into array
# Out:
# numpy.ndarray

# %%
b_asarray = np.asarray(b)
np.asarray(b)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#convert 3x3 matrix into numpy array
num_matrix = np.matrix([[1,2,3],[4,5,6],[7,8,9]])

# %%
type(num_matrix)
# Out:
# numpy.matrix

# %%
num_array = np.asarray(num_matrix) #convert matrix into array

# %%
# x = np.linspace(0, 2, 100)

# # Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
# fig, ax = plt.subplots()  # Create a figure and an axes.
# ax.plot(x, x, label='Linear')  # Plot some data on the axes.
# ax.plot(x, x**2, label='Quadratic')  # Plot more data on the axes...
# ax.plot(x, x**3, label='Cubic')  # ... and some more.
# ax.set_xlabel('x label')  # Add an x-label to the axes.
# ax.set_ylabel('y label')  # Add a y-label to the axes.
# ax.set_title("Simple Plot")  # Add a title to the axes.
# ax.legend()  # Add a legend.

# %%
number = np.random.rand(5)
ffg, aax = plt.subplots()
aax.set_xlabel('x axis')
aax.set_ylabel('y axis')
aax.set_title("Testing Demo")
aax.plt(num, num, label = 'Linear')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-7c1b2244afa7> in <module>
#       4 aax.set_ylabel('y axis')
#       5 aax.set_title("Testing Demo")
# ----> 6 aax.plt(num, num, label = 'Linear')
#
# AttributeError: 'AxesSubplot' object has no attribute 'plt'

# %%
n = np.linspace(0,2,12)
plt.subplots()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Testing Demo')

plt.plot(n,n, label='Linear')
plt.plot(n,n**2, label='Quadratic')
plt.plot(n,n**3,label = 'Qubic')

plt.legend()

# %%
np.linspace(0,2,12).reshape(3,4).ndim
# Out:
# 2

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph

    Parameters
    ----------
    ax : Axes
        The axes to draw to

    data1 : array
       The x data

    data2 : array
       The y data

    param_dict : dict
       Dictionary of kwargs to pass to ax.plot

    Returns
    -------
    out : list
        list of artists added
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4,20)
fig, ax = plt.subplots()
my_plotter(ax, data1, data2, {'marker': 'x'})

# %%
# fig = plt.subplots()
# fig, ax = plt.subplots()
# fig, ax = plt.subplots(1,1)

# %%
def students(*name):
    print(name[0], name[1])
        
students(101,'Rajib')
students(102,'Saidul',3.33)
students(102,'Islam',3.33,'saidulislamrajib97@gmail.com')
# Out:
# 101 Rajib
# 102 Saidul
# 102 Islam

# %%
def person(**details):
    print(details['id'])

    
person(id=101, name='Rajib')
person(id=102, name='Saidul',gpa= 3.33)
# Out:
# 101
# 102

# %%
def my_function(*info):

#     plt.xlabel('x axis')
#     plt.ylabel('y axis')
#     plt.title('Testing Demo')
    plt.subplots(1,1)
    plt.plot(info,info, label='Linear')
    plt.plot(info,info[0]**2, label='Quadratic')
    plt.plot(info,info**3, label='Qubic')
    



my_function(101,5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-209-3a1a8ca39fe9> in <module>
#      12
#      13
# ---> 14 my_function(101,5)
#      15
#      16
#
# <ipython-input-209-3a1a8ca39fe9> in my_function(*info)
#       6     plt.subplots(1,1)
#       7     plt.plot(info,info, label='Linear')
# ----> 8     plt.plot(info,info[0]**2, label='Quadratic')
#       9     plt.plot(info,info**3, label='Qubic')
#      10
#
# c:\users\saidu\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
def my_plotter(data1, data2, param_dict):

    return plt.plot(data1, data2, **param_dict)

data1, data2 = np.random.rand(2,10)
plt.subplots(1, 1)
my_plotter(data1, data2, {'marker': 'x'})
plt.show()

# %%
data1
# Out:
# array([0.06020394, 0.87494918, 0.15395451, 0.78244828, 0.49614818,
#        0.5008245 , 0.22282167, 0.18795363, 0.82025609, 0.02900976])

# %%
data2
# Out:
# array([0.92846593, 0.29356739, 0.05811448, 0.25103428, 0.57777222,
#        0.38113076, 0.9015184 , 0.76676233, 0.24884564, 0.59746149])

# %%
import matplotlib.pyplot as plt
plt.ioff()
plt.plot([1.6, 2.7])

# %%
ax = plt.gca()
ax.plot([2.2, 3.1])
